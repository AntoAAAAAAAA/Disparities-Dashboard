# %%
import pandas as pd
#https://www.census.gov/programs-surveys/popest/technical-documentation/research/evaluation-estimates/2020-evaluation-estimates/2010s-county-detail.html
#https://www2.census.gov/programs-surveys/popest/technical-documentation/file-layouts/2010-2020/cc-est2020-alldata.pdf

# %%
data = pd.read_csv('CC-EST2020-ALLDATA-48.csv')
data.drop(columns=['SUMLEV','STATE','COUNTY'], inplace=True)
data.rename(columns={'CTYNAME':'COUNTYNAME'}, inplace=True)
select_columns = ['STNAME', 'COUNTYNAME', 'YEAR', 'AGEGRP', 
                  #totals 
                  'TOT_POP', 'TOT_MALE', 'TOT_FEMALE',
                  'WA_MALE', 'WA_FEMALE', 'BA_MALE', 'BA_FEMALE', 'IA_MALE', 'IA_FEMALE', 'AA_MALE',
                  'AA_FEMALE', 'NA_MALE', 'NA_FEMALE', 
                  #not hispanic
                  'NH_MALE', 'NH_FEMALE', 'NHWA_MALE', 'NHWA_FEMALE','NHBA_MALE','NHBA_FEMALE',
                  'NHIA_MALE','NHIA_FEMALE','NHAA_MALE','NHAA_FEMALE','NHNA_MALE', 'NHNA_FEMALE',
                  #hispanic 
                  'H_MALE', 'H_FEMALE','HWA_MALE','HWA_FEMALE','HBA_MALE','HBA_FEMALE','HIA_MALE',
                  'HIA_FEMALE','HAA_MALE','HAA_FEMALE','HNA_MALE','HNA_FEMALE']
finaldata = data[select_columns].copy()

hmap = {1:2010, 2:2010, 3:2010, 4:2011, 5:2012, 6:2013, 7:2014, 8:2015, 9:2016, 10:2017,
        11:2018, 12:2019, 13:2020}

finaldata['YEAR'] = finaldata['YEAR'].map(hmap)
finaldata
# or 
# for index in data.index:
#     old_value = data.loc[index, 'YEAR']
#     new_value = hmap[old_value]
#     data.loc[index, 'YEAR'] = new_value
# Out:
#       STNAME       COUNTYNAME  YEAR  AGEGRP  TOT_POP  TOT_MALE  TOT_FEMALE  \
# 0      Texas  Anderson County  2010       0    58458     35521       22937
# 1      Texas  Anderson County  2010       1     3135      1566        1569
# 2      Texas  Anderson County  2010       2     3258      1729        1529
# 3      Texas  Anderson County  2010       3     3156      1573        1583
# 4      Texas  Anderson County  2010       4     3107      1676        1431
# ...      ...              ...   ...     ...      ...       ...         ...
# 62733  Texas    Zavala County  2020      14      535       266         269
# 62734  Texas    Zavala County  2020      15      477       196         281
# 62735  Texas    Zavala County  2020      16      312       135         177
# 62736  Texas    Zavala County  2020      17      208        98         110
# 62737  Texas    Zavala County  2020      18      204        82         122
#
#        WA_MALE  WA_FEMALE  BA_MALE  ...  HWA_MALE  HWA_FEMALE  HBA_MALE  \
# 0        25452      18774     9172  ...      5701        2669       276
# 1         1235       1173      225  ...       375         303        13
# 2         1362       1200      279  ...       367         315        12
# 3         1256       1254      256  ...       275         309        14
# 4         1303       1136      323  ...       323         255         7
# ...        ...        ...      ...  ...       ...         ...       ...
# 62733      250        260        4  ...       233         245         1
# 62734      188        273        3  ...       175         254         3
# 62735      135        172        0  ...       117         158         0
# 62736       96        110        1  ...        84          96         0
# 62737       79        121        0  ...        69         114         0
#
#        HBA_FEMALE  HIA_MALE  HIA_FEMALE  HAA_MALE  HAA_FEMALE  HNA_MALE  \
# 0             106       112          56       106          18        31
# 1              20         9           3         6           2         3
# 2              11         8           4         0           3         8
# 3              15         5           7         1           2         1
# 4              10         9          10         1           0         2
# ...           ...       ...         ...       ...         ...       ...
# 62733           0         5           2         1           0         1
# 62734           1         3           1         0           1         0
# 62735           1         0           1         0           0         0
# 62736           0         0           0         0           0         0
# 62737           0         1           0         0           1         0
#
#        HNA_FEMALE
# 0              24
# 1               1
# 2               4
# 3               3
# 4               2
# ...           ...
# 62733           1
# 62734           1
# 62735           0
# 62736           0
# 62737           0
#
# [62738 rows x 41 columns]
